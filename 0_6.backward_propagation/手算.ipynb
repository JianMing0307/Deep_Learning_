# %%
from IPython.display import Image
# %matplotlib inline

# %% [markdown]
# # Forward Propagation

# %%
Image(filename='img/1.png', width=1000)

# %% [markdown]
# # Backward Propagation

# %%
Image(filename='img/2.png', width=1000)
