# %% [markdown]
# # (LSTM)

# %%
from IPython.display import Image
Images = ['img/1.jpg','img/2.jpg','img/3.jpg','img/4.jpg','img/5.jpg','img/6.jpg','img/7.jpg'] 

for path in Images:
    display(Image(filename=path))

# %% [markdown]
# #

# %% [markdown]
# #

# %% [markdown]
# #

# %% [markdown]
# #

# %% [markdown]
# # (GRU)

# %%
from IPython.display import Image
Images = ['img/8.jpg','img/9.jpg','img/10.jpg','img/11.jpg','img/12.jpg','img/13.jpg'] 

for path in Images:
    display(Image(filename=path))
