# %%
from IPython.display import Image
Image("img/1.jpg")

# %% [markdown]
# # 00-(資料清洗)
# ## 透過正則表達式 : re/參考第一階段Python

# %% [markdown]
# #

# %% [markdown]
# #

# %% [markdown]
# #

# %% [markdown]
# # 10-(斷句/分詞)

# %%
# Anaconda 已內建
#!pip install nltk

# %%
Image("img/2.jpg")

# %%
import nltk

# %%
nltk.download()#----->語言文章資料庫/會出現選擇視窗,執行過一次就可
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# True

# %%
# 透過 fileid 可以找到該語料庫底下的文本檔有哪些
from nltk.corpus import gutenberg
gutenberg.fileids()
# Out:
# ['austen-emma.txt',
#  'austen-persuasion.txt',
#  'austen-sense.txt',
#  'bible-kjv.txt',
#  'blake-poems.txt',
#  'bryant-stories.txt',
#  'burgess-busterbrown.txt',
#  'carroll-alice.txt',
#  'chesterton-ball.txt',
#  'chesterton-brown.txt',
#  'chesterton-thursday.txt',
#  'edgeworth-parents.txt',
#  'melville-moby_dick.txt',
#  'milton-paradise.txt',
#  'shakespeare-caesar.txt',
#  'shakespeare-hamlet.txt',
#  'shakespeare-macbeth.txt',
#  'whitman-leaves.txt']

# %%
# 測試文章段落
text="Today is a great day. It is even better than yesterday." + \
     " And yesterday was the best day ever."

# %%
# 分割字句
nltk.sent_tokenize(text)
# Out:
# ['Today is a great day.',
#  'It is even better than yesterday.',
#  'And yesterday was the best day ever.']

# %%
# 分詞
nltk.word_tokenize(text)
# Out:
# ['Today',
#  'is',
#  'a',
#  'great',
#  'day',
#  '.',
#  'It',
#  'is',
#  'even',
#  'better',
#  'than',
#  'yesterday',
#  '.',
#  'And',
#  'yesterday',
#  'was',
#  'the',
#  'best',
#  'day',
#  'ever',
#  '.']

# %%
# !pip install paddlepaddle
# Out:
# ...
# WARNING: Ignoring invalid distribution -treamlit (d:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -treamlit (d:\anaconda\lib\site-packages)

# %%
# !pip install jieba
# Out:
# ^C

# %% [markdown]
# ## /(分詞模式)

# %%
# encoding=utf-8
import jieba

jieba.enable_paddle()# 啟用paddle模式
# Out:
# ...
# WARNING: Ignoring invalid distribution -treamlit (d:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -treamlit (d:\anaconda\lib\site-packages)
# Import error, cannot find paddle.fluid and jieba.lac_small.predict module. Now, back to jieba basic cut......
# [2023-12-18 15:12:05,727] [   DEBUG] _compat.py:50 - Import error, cannot find paddle.fluid and jieba.lac_small.predict module. Now, back to jieba basic cut......

# %%
strs = "我來到台北的台灣大學"

seg_list = jieba.cut(strs, cut_all=True)
print("Full Mode: " + "/ ".join(seg_list))  # 全模式--->較快
seg_list = jieba.cut(strs, cut_all=False)
print("Default Mode: " + "/ ".join(seg_list))  # 精確模式
seg_list = jieba.cut(strs, use_paddle=True)
print("Paddele mode: " + "/ ".join(seg_list))  # paddle模式
seg_list = jieba.cut_for_search(strs)
print("Search mode: " + "/ ".join(seg_list))  # 搜索引擎模式
# Out:
# Full Mode: 我/ 來/ 到/ 台北/ 的/ 台灣大學
# Default Mode: 我來/ 到/ 台北/ 的/ 台灣大學
# Paddele mode: 我來/ 到/ 台北/ 的/ 台灣大學
# Search mode: 我來/ 到/ 台北/ 的/ 台灣大學

# %% [markdown]
# ## /(停用詞)

# %%
Image("img/6.jpg")

# %%
import string
print('標點符號:', string.punctuation)
# Out:
# 標點符號: !"#$%&'()*+,-./:;<=>?@[\]^_`{|}~

# %%
# nltk.corpus.stopwords
nltk.corpus.stopwords.words('english')
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
# ...

# %%
# 標點符號(Punctuation)
import string
print('標點符號:', string.punctuation)

# 測試文章段落
text="Today is a great day. It is even better than yesterday." + \
     " And yesterday was the best day ever."
# 讀取停用詞
stopword_list = set(nltk.corpus.stopwords.words('english') 
                    + list(string.punctuation))

# 移除停用詞(Removing Stopwords)
def remove_stopwords(text, is_lower_case=False):
    if is_lower_case:
        text = text.lower()
    tokens = nltk.word_tokenize(text)
    tokens = [token.strip() for token in tokens]
    filtered_tokens = [token for token in tokens if token not in stopword_list]
    filtered_text = ' '.join(filtered_tokens)    
    return filtered_text, filtered_tokens

filtered_text, filtered_tokens = remove_stopwords(text) 
filtered_text

# %%
seg_list = jieba.cut(strs, cut_all=True) #----->剪完放到暫存區
# print("Full Mode: " + "/ ".join(seg_list)) #----->seg_list從暫群區取出來就會清空(取一個加/再取一個加/再取一個加/)
# print(seg_list)

#去掉停用詞
stopwords = ['來','的']
word_list = []
for seg in seg_list:
    if seg not in stopwords:
        word_list.append(seg)

print('啟用停用詞過濾後：\n', '/'.join(word_list))
# Out:
# 啟用停用詞過濾後：
#  我/到/台北/台灣大學

# %% [markdown]
# ## /(自訂義詞)

# %%
Image("img/7.jpg")

# %%
jieba.load_userdict('myText.txt')

seg_list = jieba.lcut(strs) #lcut: cut後直接形成list / cut:for迴圈完另存list
print(seg_list)
# Out:
# ['我來', '到', '台北', '的', '台灣大學']

# %% [markdown]
# # 20-(詞形還原)

# %%
Image("img/3.jpg") #----->中文沒有這困擾

# %%
Image("img/8.jpg")

# %%
from nltk.stem import PorterStemmer, LancasterStemmer, SnowballStemmer

tokens = ["the", "spectators", "all", "stood", "and", "sang", "the", "national", "anthem"]

# stemming
port = PorterStemmer()#----->運用現有的規則移除常見單詞字尾
stemmed_port = [port.stem(token) for token in tokens]

lanc = LancasterStemmer()#----->有超過120條規則來刪除或替換詞綴。
stemmed_lanc = [lanc.stem(token) for token in tokens]

snow = SnowballStemmer("english")#----->支援多種語言加以優化辨識,精準度較高
stemmed_snow = [snow.stem(token) for token in tokens]

# showing stemmed results
print("Porter: {}".format(stemmed_port)) 
print("Lancaster: {}".format(stemmed_lanc))
print("Snowball: {}".format(stemmed_snow))

# %% [markdown]
# ## /PorterStemmer()

# %%
word = 'changes'
ps = nltk.porter.PorterStemmer()
ps.stem(word)

# %%
# 字根詞形還原(Stemming)X
text="Today is a great day. It is even better than yesterday." + \
     " And yesterday was the best day ever."
ps = nltk.porter.PorterStemmer()
ps_text = ' '.join([ps.stem(word) for word in text.split()])
ps_text

# %%
# 字根詞形還原(Stemming)X
ps = nltk.porter.PorterStemmer()
' '.join([ps.stem(word) for word in nltk.word_tokenize(text)])

# %% [markdown]
# ## /Lemmatizer()

# %%
from nltk.stem import WordNetLemmatizer #----->載入WordNet語料庫

wnl = WordNetLemmatizer()
# lemmatize nouns
print(wnl.lemmatize('cars', 'n'))#單詞，指定詞性：名詞
print(wnl.lemmatize('men', 'n'))

# lemmatize verbs
print(wnl.lemmatize('running', 'v'))
print(wnl.lemmatize('ate', 'v'))

# lemmatize adjectives
print(wnl.lemmatize('saddest', 'a'))
print(wnl.lemmatize('fancier', 'a'))

# %%
word = 'crashed'
lem = nltk.WordNetLemmatizer()
lem.lemmatize(word)

# %%
text = 'My system keeps crashing his crashed yesterday, ours crashes daily'
lem = nltk.WordNetLemmatizer()
' '.join([lem.lemmatize(word) for word in text.split()])

# %% [markdown]
# # 30-(詞性標註)

# %%
Image("img/4.jpg") #----->航太/軍事/醫療另外自訂

# %%
import jieba.posseg as pseg

words = pseg.cut(strs)
for word, flag in words:
    # 格式化模版並傳入參數
    print('%s, %s' % (word, flag))
# Out:
# 我, r
# 來, v
# 到, v
# 台北, ns
# 的, uj
# 台灣大學, x

# %%
Image("img/5.jpg")
