# %%
from IPython.display import Image

# %%
Image("img/TL.jpg")

# %% [markdown]
# # 1. 模型全採用

# %%
Image("img/tlall.jpg")

# %%
Image("img/tlparams.jpg")

# %% [markdown]
# # 2. 將模型當成特徵提取器

# %%
Image("img/partialtl.jpg")

# %%
Image("img/strategyoftl.jpg")
