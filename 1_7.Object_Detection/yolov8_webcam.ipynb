# %% [markdown]
# 資料來源：https://dipankarmedh1.medium.com/real-time-object-detection-with-yolo-and-webcam-enhancing-your-computer-vision-skills-861b97c78993

# %% [markdown]
# https://docs.ultralytics.com/zh/tasks/classify/
# https://github.com/ultralytics/ultralytics/tree/main/ultralytics/cfg/datasets

# %% [markdown]
# # (Webcam辨識)

# %%
# !pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in /Users/elsawang/anaconda3/lib/python3.11/site-packages (4.8.1.78)
# Requirement already satisfied: numpy>=1.21.2 in /Users/elsawang/anaconda3/lib/python3.11/site-packages (from opencv-python) (1.24.3)

# %%
# !pip install ultralytics

# %% [markdown]
# cv2.set()參數：
# https://blog.csdn.net/weixin_47965042/article/details/113359922

# %%
from ultralytics import YOLO
import cv2
import math 

# start webcam
cap = cv2.VideoCapture(0)
#cap = cv2.VideoCapture('影片路徑') # 讀取電腦中的影片,cv2.CAP_DSHOW
cap.set(3, 640)#3:每一幀的寬
cap.set(4, 480)#4:每一幀的高
if not cap.isOpened():
    print("Cannot open camera")
    exit()
# Out:
# Cannot open camera
# 在目前儲存格或上一個儲存格中執行程式碼時，Kernel 已損毀。請檢閱儲存格中的程式碼，找出失敗的可能原因。如需詳細資訊，請按一下<a href='https://aka.ms/vscodeJupyterKernelCrash'>這裡</a>。檢視 Jupyter <a href='command:jupyter.viewOutput'>記錄</a>，以取得進一步的詳細資料。

# %%
# model
model = YOLO("yolov8n.pt")

# object classes
classNames = ["person", "bicycle", "car", "motorbike", "aeroplane", "bus", "train", "truck", "boat","traffic light", "fire hydrant", "stop sign", "parking meter", "bench", "bird", "cat",    "dog", "horse", "sheep", "cow", "elephant", "bear", "zebra", "giraffe", "backpack", "umbrella","handbag", "tie", "suitcase", "frisbee", "skis", "snowboard", "sports ball", "kite", "baseball bat", "baseball glove", "skateboard", "surfboard", "tennis racket", "bottle", "wine glass", "cup",    "fork", "knife", "spoon", "bowl", "banana", "apple", "sandwich", "orange", "broccoli",         "carrot", "hot dog", "pizza", "donut", "cake", "chair", "sofa", "pottedplant", "bed",              "diningtable", "toilet", "tvmonitor", "laptop", "mouse", "remote", "keyboard", "cell phone",      "microwave", "oven", "toaster", "sink", "refrigerator", "book", "clock", "vase", "scissors", "teddy bear", "hair drier", "toothbrush"
]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19772\2229311824.py in <module>
#       1 # model
# ----> 2 model = YOLO("yolov8n.pt")
#       3
#       4 # object classes
#       5 classNames = ["person", "bicycle", "car", "motorbike", "aeroplane", "bus", "train", "truck", "boat","traffic light", "fire hydrant", "stop sign", "parking meter", "bench", "bird", "cat",    "dog", "horse", "sheep", "cow", "elephant", "bear", "zebra", "giraffe", "backpack", "umbrella","handbag", "tie", "suitcase", "frisbee", "skis", "snowboard", "sports ball", "kite", "baseball bat", "baseball glove", "skateboard", "surfboard", "tennis racket", "bottle", "wine glass", "cup",    "fork", "knife", "spoon", "bowl", "banana", "apple", "sandwich", "orange", "broccoli",         "carrot", "hot dog", "pizza", "donut", "cake", "chair", "sofa", "pottedplant", "bed",              "diningtable", "toilet", "tvmonitor", "laptop", "mouse", "remote", "keyboard", "cell phone",      "microwave", "oven", "toaster", "sink", "refrigerator", "book", "clock", "vase", "scissors", "teddy bear", "hair drier", "toothbrush"
#
# NameError: name 'YOLO' is not defined

# %%
while True:
    success, img = cap.read()
    results = model(img, stream=True)

    # coordinates
    for r in results:
        boxes = r.boxes

        for box in boxes:
            # bounding box
            x1, y1, x2, y2 = box.xyxy[0]
            x1, y1, x2, y2 = int(x1), int(y1), int(x2), int(y2) # convert to int values

            # put box in cam
            cv2.rectangle(img, (x1, y1), (x2, y2), (255, 0, 255), 3)

            # confidence
            confidence = math.ceil((box.conf[0]*100))/100
            print("Confidence --->",confidence)

            # class name
            cls = int(box.cls[0])
            print("Class name -->", classNames[cls])

            # object details
            org = [x1, y1]
            font = cv2.FONT_HERSHEY_SIMPLEX
            fontScale = 1
            color = (255, 0, 0)
            thickness = 2

            cv2.putText(img, classNames[cls], org, font, fontScale, color, thickness)

    cv2.imshow('Webcam', img)
    if cv2.waitKey(1) == ord('q'):
        cv2.imwrite("imgs.jpg", img)
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# Confidence ---> 0.38
# Class name --> traffic light
# Confidence ---> 0.37
# Class name --> tvmonitor
# Confidence ---> 0.34
# Class name --> tvmonitor
# 0: 480x640 1 traffic light, 2 tvs, 263.2ms
# Speed: 10.0ms preprocess, 263.2ms inference, 18.5ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.37
# Class name --> tvmonitor
# Confidence ---> 0.34
# Class name --> tvmonitor
# 0: 480x640 2 tvs, 160.5ms
# Speed: 3.2ms preprocess, 160.5ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.42
# Class name --> tvmonitor
# Confidence ---> 0.33
# Class name --> tvmonitor
# Confidence ---> 0.28
# Class name --> traffic light
# 0: 480x640 1 traffic light, 2 tvs, 211.0ms
# Speed: 1.7ms preprocess, 211.0ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.32
# Class name --> tvmonitor
# Confidence ---> 0.3
# Class name --> traffic light
# Confidence ---> 0.29
# Class name --> tvmonitor
# 0: 480x640 1 traffic light, 2 tvs, 179.4ms
# Speed: 2.3ms preprocess, 179.4ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.3
# Class name --> tvmonitor
# Confidence ---> 0.29
# Class name --> tvmonitor
# 0: 480x640 2 tvs, 153.9ms
# Speed: 1.5ms preprocess, 153.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# 2023-12-07 19:34:34.705 python[59384:1332667] _TIPropertyValueIsValid called with 4 on nil context!
# 2023-12-07 19:34:34.705 python[59384:1332667] imkxpc_getApplicationProperty:reply: called with incorrect property value 4, bailing.
# 2023-12-07 19:34:34.705 python[59384:1332667] Text input context does not respond to _valueForTIProperty:
# Confidence ---> 0.39
# Class name --> tvmonitor
# Confidence ---> 0.29
# Class name --> tvmonitor
# 0: 480x640 2 tvs, 183.9ms
# Speed: 4.5ms preprocess, 183.9ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.36
# Class name --> tvmonitor
# Confidence ---> 0.29
# Class name --> tvmonitor
# 0: 480x640 2 tvs, 162.6ms
# Speed: 1.4ms preprocess, 162.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# 2023-12-07 19:34:34.927 python[59384:1332667] _TIPropertyValueIsValid called with 4 on nil context!
# 2023-12-07 19:34:34.927 python[59384:1332667] imkxpc_getApplicationProperty:reply: called with incorrect property value 4, bailing.
# 2023-12-07 19:34:34.927 python[59384:1332667] Text input context does not respond to _valueForTIProperty:
# 2023-12-07 19:34:34.928 python[59384:1332667] _TIPropertyValueIsValid called with 4 on nil context!
# 2023-12-07 19:34:34.928 python[59384:1332667] imkxpc_getApplicationProperty:reply: called with incorrect property value 4, bailing.
# 2023-12-07 19:34:34.928 python[59384:1332667] Text input context does not respond to _valueForTIProperty:
# Confidence ---> 0.4
# Class name --> tvmonitor
# Confidence ---> 0.27
# Class name --> tvmonitor
# 0: 480x640 2 tvs, 168.3ms
# Speed: 1.5ms preprocess, 168.3ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.37
# Class name --> tvmonitor
# Confidence ---> 0.27
# Class name --> tvmonitor
# 0: 480x640 2 tvs, 164.7ms
# Speed: 1.8ms preprocess, 164.7ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.39
# Class name --> tvmonitor
# Confidence ---> 0.27
# Class name --> teddy bear
# 0: 480x640 1 tv, 1 teddy bear, 168.1ms
# Speed: 1.7ms preprocess, 168.1ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.33
# Class name --> tvmonitor
# Confidence ---> 0.32
# Class name --> tvmonitor
# 0: 480x640 2 tvs, 165.7ms
# Speed: 2.0ms preprocess, 165.7ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.3
# Class name --> tvmonitor
# Confidence ---> 0.26
# Class name --> traffic light
# 0: 480x640 1 traffic light, 1 tv, 162.9ms
# Speed: 1.4ms preprocess, 162.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.33
# Class name --> traffic light
# Confidence ---> 0.29
# Class name --> tvmonitor
# 0: 480x640 1 traffic light, 1 tv, 164.7ms
# Speed: 1.5ms preprocess, 164.7ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.65
# Class name --> traffic light
# Confidence ---> 0.32
# Class name --> tvmonitor
# Confidence ---> 0.29
# Class name --> tvmonitor
# 0: 480x640 1 traffic light, 2 tvs, 160.2ms
# Speed: 1.4ms preprocess, 160.2ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.53
# Class name --> traffic light
# Confidence ---> 0.34
# Class name --> tvmonitor
# Confidence ---> 0.27
# Class name --> tvmonitor
# 0: 480x640 1 traffic light, 2 tvs, 151.6ms
# Speed: 1.4ms preprocess, 151.6ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.49
# Class name --> traffic light
# Confidence ---> 0.38
# Class name --> tvmonitor
# Confidence ---> 0.3
# Class name --> tvmonitor
# 0: 480x640 1 traffic light, 2 tvs, 179.7ms
# Speed: 2.0ms preprocess, 179.7ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.51
# Class name --> traffic light
# Confidence ---> 0.4
# Class name --> tvmonitor
# Confidence ---> 0.27
# Class name --> tvmonitor
# 0: 480x640 1 traffic light, 2 tvs, 151.4ms
# Speed: 1.5ms preprocess, 151.4ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.41
# Class name --> traffic light
# Confidence ---> 0.33
# Class name --> tvmonitor
# Confidence ---> 0.27
# Class name --> tvmonitor
# 0: 480x640 1 traffic light, 2 tvs, 153.3ms
# Speed: 2.1ms preprocess, 153.3ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.5
# Class name --> tvmonitor
# Confidence ---> 0.26
# Class name --> traffic light
# 0: 480x640 1 traffic light, 1 tv, 154.6ms
# Speed: 2.4ms preprocess, 154.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.54
# Class name --> traffic light
# Confidence ---> 0.38
# Class name --> tvmonitor
# Confidence ---> 0.28
# Class name --> tvmonitor
# 0: 480x640 1 traffic light, 2 tvs, 152.9ms
# Speed: 1.8ms preprocess, 152.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.47
# Class name --> traffic light
# Confidence ---> 0.33
# Class name --> tvmonitor
# 0: 480x640 1 traffic light, 1 tv, 151.6ms
# Speed: 1.6ms preprocess, 151.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.5
# Class name --> traffic light
# Confidence ---> 0.32
# Class name --> tvmonitor
# 0: 480x640 1 traffic light, 1 tv, 161.2ms
# Speed: 1.8ms preprocess, 161.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.38
# Class name --> tvmonitor
# Confidence ---> 0.33
# Class name --> traffic light
# Confidence ---> 0.28
# Class name --> tvmonitor
# 0: 480x640 1 traffic light, 2 tvs, 154.9ms
# Speed: 1.6ms preprocess, 154.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.66
# Class name --> traffic light
# Confidence ---> 0.38
# Class name --> tvmonitor
# Confidence ---> 0.28
# Class name --> tvmonitor
# 0: 480x640 1 traffic light, 2 tvs, 186.9ms
# Speed: 1.3ms preprocess, 186.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.63
# Class name --> traffic light
# Confidence ---> 0.33
# Class name --> tvmonitor
# 0: 480x640 1 traffic light, 1 tv, 152.3ms
# Speed: 1.3ms preprocess, 152.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.59
# Class name --> traffic light
# Confidence ---> 0.38
# Class name --> tvmonitor
# Confidence ---> 0.27
# Class name --> tvmonitor
# 0: 480x640 1 traffic light, 2 tvs, 159.0ms
# Speed: 1.4ms preprocess, 159.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.57
# Class name --> traffic light
# Confidence ---> 0.38
# Class name --> tvmonitor
# Confidence ---> 0.26
# Class name --> tvmonitor
# 0: 480x640 1 traffic light, 2 tvs, 147.2ms
# Speed: 1.7ms preprocess, 147.2ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.45
# Class name --> traffic light
# Confidence ---> 0.33
# Class name --> tvmonitor
# Confidence ---> 0.27
# Class name --> tvmonitor
# 0: 480x640 1 traffic light, 2 tvs, 147.7ms
# Speed: 1.5ms preprocess, 147.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.56
# Class name --> traffic light
# Confidence ---> 0.3
# Class name --> tvmonitor
# 0: 480x640 1 traffic light, 1 tv, 152.8ms
# Speed: 1.4ms preprocess, 152.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.38
# Class name --> tvmonitor
# 0: 480x640 1 tv, 149.3ms
# Speed: 1.8ms preprocess, 149.3ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.3
# Class name --> tvmonitor
# 0: 480x640 1 tv, 145.7ms
# Speed: 1.3ms preprocess, 145.7ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.38
# Class name --> tvmonitor
# 0: 480x640 1 tv, 154.2ms
# Speed: 1.6ms preprocess, 154.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.44
# Class name --> tvmonitor
# Confidence ---> 0.29
# Class name --> tvmonitor
# 0: 480x640 2 tvs, 154.2ms
# Speed: 1.4ms preprocess, 154.2ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.3
# Class name --> tvmonitor
# Confidence ---> 0.27
# Class name --> tvmonitor
# 0: 480x640 2 tvs, 152.4ms
# Speed: 2.2ms preprocess, 152.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.56
# Class name --> tvmonitor
# Confidence ---> 0.45
# Class name --> chair
# Confidence ---> 0.28
# Class name --> skateboard
# 0: 480x640 1 skateboard, 1 chair, 1 tv, 150.9ms
# Speed: 2.0ms preprocess, 150.9ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.39
# Class name --> chair
# Confidence ---> 0.32
# Class name --> tvmonitor
# 0: 480x640 1 chair, 1 tv, 144.6ms
# Speed: 1.6ms preprocess, 144.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.49
# Class name --> tvmonitor
# 0: 480x640 1 tv, 145.0ms
# Speed: 1.6ms preprocess, 145.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 151.8ms
# Speed: 1.9ms preprocess, 151.8ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 154.9ms
# Speed: 1.7ms preprocess, 154.9ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.37
# Class name --> umbrella
# Confidence ---> 0.34
# Class name --> umbrella
# Confidence ---> 0.26
# Class name --> orange
# 0: 480x640 2 umbrellas, 1 orange, 149.9ms
# Speed: 1.6ms preprocess, 149.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.41
# Class name --> bird
# 0: 480x640 1 bird, 153.5ms
# Speed: 1.3ms preprocess, 153.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 152.6ms
# Speed: 1.5ms preprocess, 152.6ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 156.2ms
# Speed: 1.5ms preprocess, 156.2ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.55
# Class name --> motorbike
# 0: 480x640 1 motorcycle, 155.0ms
# Speed: 1.6ms preprocess, 155.0ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.44
# Class name --> motorbike
# 0: 480x640 1 motorcycle, 146.6ms
# Speed: 1.4ms preprocess, 146.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.54
# Class name --> mouse
# Confidence ---> 0.33
# Class name --> mouse
# Confidence ---> 0.29
# Class name --> teddy bear
# 0: 480x640 2 mouses, 1 teddy bear, 150.1ms
# Speed: 1.3ms preprocess, 150.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.56
# Class name --> orange
# Confidence ---> 0.35
# Class name --> teddy bear
# Confidence ---> 0.27
# Class name --> tvmonitor
# Confidence ---> 0.26
# Class name --> mouse
# 0: 480x640 1 orange, 1 tv, 1 mouse, 1 teddy bear, 190.0ms
# Speed: 1.3ms preprocess, 190.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.69
# Class name --> orange
# Confidence ---> 0.49
# Class name --> scissors
# 0: 480x640 1 orange, 1 scissors, 154.3ms
# Speed: 1.5ms preprocess, 154.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.73
# Class name --> scissors
# Confidence ---> 0.46
# Class name --> scissors
# Confidence ---> 0.45
# Class name --> orange
# Confidence ---> 0.39
# Class name --> book
# Confidence ---> 0.29
# Class name --> teddy bear
# 0: 480x640 1 orange, 1 book, 2 scissorss, 1 teddy bear, 150.9ms
# Speed: 1.5ms preprocess, 150.9ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.8
# Class name --> scissors
# 0: 480x640 1 scissors, 151.5ms
# Speed: 1.5ms preprocess, 151.5ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.83
# Class name --> scissors
# Confidence ---> 0.4
# Class name --> teddy bear
# Confidence ---> 0.3
# Class name --> diningtable
# 0: 480x640 1 dining table, 1 scissors, 1 teddy bear, 149.6ms
# Speed: 2.0ms preprocess, 149.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.26
# Class name --> teddy bear
# 0: 480x640 1 teddy bear, 148.6ms
# Speed: 2.2ms preprocess, 148.6ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.46
# Class name --> teddy bear
# Confidence ---> 0.35
# Class name --> scissors
# Confidence ---> 0.29
# Class name --> scissors
# 0: 480x640 2 scissorss, 1 teddy bear, 154.3ms
# Speed: 1.5ms preprocess, 154.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 151.4ms
# Speed: 1.3ms preprocess, 151.4ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.47
# Class name --> teddy bear
# Confidence ---> 0.32
# Class name --> clock
# Confidence ---> 0.28
# Class name --> bowl
# 0: 480x640 1 bowl, 1 clock, 1 teddy bear, 150.2ms
# Speed: 1.5ms preprocess, 150.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.65
# Class name --> teddy bear
# 0: 480x640 1 teddy bear, 149.4ms
# Speed: 1.9ms preprocess, 149.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.45
# Class name --> teddy bear
# 0: 480x640 1 teddy bear, 149.0ms
# Speed: 1.5ms preprocess, 149.0ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.42
# Class name --> teddy bear
# 0: 480x640 1 teddy bear, 159.1ms
# Speed: 1.4ms preprocess, 159.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.56
# Class name --> teddy bear
# 0: 480x640 1 teddy bear, 160.7ms
# Speed: 3.1ms preprocess, 160.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.48
# Class name --> teddy bear
# Confidence ---> 0.4
# Class name --> knife
# 0: 480x640 1 knife, 1 teddy bear, 152.8ms
# Speed: 1.4ms preprocess, 152.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.58
# Class name --> teddy bear
# Confidence ---> 0.28
# Class name --> knife
# 0: 480x640 1 knife, 1 teddy bear, 152.5ms
# Speed: 1.8ms preprocess, 152.5ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.44
# Class name --> teddy bear
# 0: 480x640 1 teddy bear, 152.8ms
# Speed: 1.9ms preprocess, 152.8ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.64
# Class name --> teddy bear
# Confidence ---> 0.47
# Class name --> clock
# 0: 480x640 1 clock, 1 teddy bear, 152.7ms
# Speed: 1.4ms preprocess, 152.7ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.59
# Class name --> teddy bear
# Confidence ---> 0.28
# Class name --> knife
# 0: 480x640 1 knife, 1 teddy bear, 150.8ms
# Speed: 1.6ms preprocess, 150.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.49
# Class name --> teddy bear
# Confidence ---> 0.35
# Class name --> knife
# 0: 480x640 1 knife, 1 teddy bear, 149.4ms
# Speed: 1.4ms preprocess, 149.4ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.56
# Class name --> teddy bear
# Confidence ---> 0.28
# Class name --> knife
# 0: 480x640 1 knife, 1 teddy bear, 144.4ms
# Speed: 1.3ms preprocess, 144.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.5
# Class name --> teddy bear
# Confidence ---> 0.27
# Class name --> knife
# 0: 480x640 1 knife, 1 teddy bear, 159.9ms
# Speed: 1.7ms preprocess, 159.9ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.55
# Class name --> teddy bear
# Confidence ---> 0.34
# Class name --> scissors
# 0: 480x640 1 scissors, 1 teddy bear, 195.4ms
# Speed: 2.2ms preprocess, 195.4ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.61
# Class name --> scissors
# Confidence ---> 0.49
# Class name --> teddy bear
# Confidence ---> 0.35
# Class name --> knife
# 0: 480x640 1 knife, 1 scissors, 1 teddy bear, 148.4ms
# Speed: 1.6ms preprocess, 148.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.5
# Class name --> teddy bear
# 0: 480x640 1 teddy bear, 150.7ms
# Speed: 1.4ms preprocess, 150.7ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.57
# Class name --> teddy bear
# Confidence ---> 0.26
# Class name --> scissors
# 0: 480x640 1 scissors, 1 teddy bear, 150.4ms
# Speed: 1.5ms preprocess, 150.4ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.58
# Class name --> teddy bear
# Confidence ---> 0.27
# Class name --> knife
# 0: 480x640 1 knife, 1 teddy bear, 150.9ms
# Speed: 1.8ms preprocess, 150.9ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.68
# Class name --> teddy bear
# Confidence ---> 0.31
# Class name --> scissors
# Confidence ---> 0.26
# Class name --> knife
# 0: 480x640 1 knife, 1 scissors, 1 teddy bear, 154.2ms
# Speed: 1.5ms preprocess, 154.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.59
# Class name --> teddy bear
# Confidence ---> 0.31
# Class name --> knife
# 0: 480x640 1 knife, 1 teddy bear, 152.4ms
# Speed: 1.7ms preprocess, 152.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.47
# Class name --> teddy bear
# Confidence ---> 0.44
# Class name --> knife
# 0: 480x640 1 knife, 1 teddy bear, 150.6ms
# Speed: 1.6ms preprocess, 150.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.57
# Class name --> teddy bear
# 0: 480x640 1 teddy bear, 147.5ms
# Speed: 1.5ms preprocess, 147.5ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.58
# Class name --> teddy bear
# Confidence ---> 0.28
# Class name --> knife
# 0: 480x640 1 knife, 1 teddy bear, 146.2ms
# Speed: 1.4ms preprocess, 146.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.58
# Class name --> teddy bear
# Confidence ---> 0.36
# Class name --> knife
# Confidence ---> 0.26
# Class name --> scissors
# 0: 480x640 1 knife, 1 scissors, 1 teddy bear, 156.4ms
# Speed: 1.6ms preprocess, 156.4ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.59
# Class name --> teddy bear
# Confidence ---> 0.33
# Class name --> knife
# 0: 480x640 1 knife, 1 teddy bear, 150.5ms
# Speed: 1.4ms preprocess, 150.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.53
# Class name --> teddy bear
# 0: 480x640 1 teddy bear, 150.3ms
# Speed: 1.4ms preprocess, 150.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.57
# Class name --> teddy bear
# Confidence ---> 0.35
# Class name --> scissors
# 0: 480x640 1 scissors, 1 teddy bear, 146.7ms
# Speed: 1.5ms preprocess, 146.7ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.63
# Class name --> teddy bear
# Confidence ---> 0.43
# Class name --> scissors
# Confidence ---> 0.3
# Class name --> knife
# 0: 480x640 1 knife, 1 scissors, 1 teddy bear, 150.3ms
# Speed: 1.5ms preprocess, 150.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.58
# Class name --> teddy bear
# 0: 480x640 1 teddy bear, 154.3ms
# Speed: 1.4ms preprocess, 154.3ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.6
# Class name --> teddy bear
# Confidence ---> 0.29
# Class name --> scissors
# Confidence ---> 0.27
# Class name --> chair
# Confidence ---> 0.26
# Class name --> knife
# 0: 480x640 1 knife, 1 chair, 1 scissors, 1 teddy bear, 147.4ms
# Speed: 1.8ms preprocess, 147.4ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.57
# Class name --> teddy bear
# 0: 480x640 1 teddy bear, 150.6ms
# Speed: 1.9ms preprocess, 150.6ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.6
# Class name --> teddy bear
# 0: 480x640 1 teddy bear, 148.2ms
# Speed: 1.6ms preprocess, 148.2ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.68
# Class name --> teddy bear
# Confidence ---> 0.27
# Class name --> toothbrush
# 0: 480x640 1 teddy bear, 1 toothbrush, 149.2ms
# Speed: 1.5ms preprocess, 149.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.66
# Class name --> teddy bear
# Confidence ---> 0.4
# Class name --> knife
# 0: 480x640 1 knife, 1 teddy bear, 148.9ms
# Speed: 1.4ms preprocess, 148.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.7
# Class name --> teddy bear
# Confidence ---> 0.26
# Class name --> toothbrush
# 0: 480x640 1 teddy bear, 1 toothbrush, 149.3ms
# Speed: 1.4ms preprocess, 149.3ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.59
# Class name --> teddy bear
# 0: 480x640 1 teddy bear, 153.9ms
# Speed: 1.4ms preprocess, 153.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.53
# Class name --> teddy bear
# 0: 480x640 1 teddy bear, 148.9ms
# Speed: 1.8ms preprocess, 148.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.56
# Class name --> teddy bear
# Confidence ---> 0.3
# Class name --> knife
# 0: 480x640 1 knife, 1 teddy bear, 161.3ms
# Speed: 2.4ms preprocess, 161.3ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.74
# Class name --> teddy bear
# 0: 480x640 1 teddy bear, 154.1ms
# Speed: 1.7ms preprocess, 154.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.55
# Class name --> teddy bear
# Confidence ---> 0.26
# Class name --> scissors
# 0: 480x640 1 scissors, 1 teddy bear, 147.4ms
# Speed: 1.4ms preprocess, 147.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.6
# Class name --> teddy bear
# 0: 480x640 1 teddy bear, 148.9ms
# Speed: 1.4ms preprocess, 148.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.65
# Class name --> teddy bear
# Confidence ---> 0.26
# Class name --> knife
# 0: 480x640 1 knife, 1 teddy bear, 152.2ms
# Speed: 1.4ms preprocess, 152.2ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.56
# Class name --> teddy bear
# Confidence ---> 0.27
# Class name --> knife
# 0: 480x640 1 knife, 1 teddy bear, 149.4ms
# Speed: 1.5ms preprocess, 149.4ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.52
# Class name --> teddy bear
# Confidence ---> 0.33
# Class name --> knife
# 0: 480x640 1 knife, 1 teddy bear, 148.6ms
# Speed: 1.6ms preprocess, 148.6ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.6
# Class name --> teddy bear
# Confidence ---> 0.3
# Class name --> knife
# 0: 480x640 1 knife, 1 teddy bear, 149.1ms
# Speed: 1.3ms preprocess, 149.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.59
# Class name --> teddy bear
# Confidence ---> 0.49
# Class name --> knife
# 0: 480x640 1 knife, 1 teddy bear, 151.3ms
# Speed: 1.4ms preprocess, 151.3ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.56
# Class name --> teddy bear
# 0: 480x640 1 teddy bear, 147.0ms
# Speed: 1.5ms preprocess, 147.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.63
# Class name --> teddy bear
# Confidence ---> 0.27
# Class name --> scissors
# 0: 480x640 1 scissors, 1 teddy bear, 145.6ms
# Speed: 1.7ms preprocess, 145.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.57
# Class name --> teddy bear
# Confidence ---> 0.31
# Class name --> knife
# Confidence ---> 0.29
# Class name --> scissors
# 0: 480x640 1 knife, 1 scissors, 1 teddy bear, 153.2ms
# Speed: 1.8ms preprocess, 153.2ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.58
# Class name --> teddy bear
# Confidence ---> 0.31
# Class name --> knife
# 0: 480x640 1 knife, 1 teddy bear, 146.4ms
# Speed: 1.4ms preprocess, 146.4ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.52
# Class name --> teddy bear
# 0: 480x640 1 teddy bear, 144.5ms
# Speed: 1.6ms preprocess, 144.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.53
# Class name --> teddy bear
# Confidence ---> 0.37
# Class name --> knife
# 0: 480x640 1 knife, 1 teddy bear, 147.5ms
# Speed: 1.5ms preprocess, 147.5ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.6
# Class name --> teddy bear
# Confidence ---> 0.28
# Class name --> scissors
# 0: 480x640 1 scissors, 1 teddy bear, 147.5ms
# Speed: 1.6ms preprocess, 147.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.55
# Class name --> teddy bear
# Confidence ---> 0.52
# Class name --> knife
# 0: 480x640 1 knife, 1 teddy bear, 150.2ms
# Speed: 2.0ms preprocess, 150.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.61
# Class name --> teddy bear
# Confidence ---> 0.27
# Class name --> knife
# 0: 480x640 1 knife, 1 teddy bear, 149.1ms
# Speed: 1.6ms preprocess, 149.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.59
# Class name --> teddy bear
# Confidence ---> 0.32
# Class name --> scissors
# 0: 480x640 1 scissors, 1 teddy bear, 158.4ms
# Speed: 1.4ms preprocess, 158.4ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.47
# Class name --> teddy bear
# 0: 480x640 1 teddy bear, 151.0ms
# Speed: 1.5ms preprocess, 151.0ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.57
# Class name --> teddy bear
# 0: 480x640 1 teddy bear, 154.1ms
# Speed: 1.5ms preprocess, 154.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.45
# Class name --> teddy bear
# 0: 480x640 1 teddy bear, 153.9ms
# Speed: 1.3ms preprocess, 153.9ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.64
# Class name --> teddy bear
# Confidence ---> 0.29
# Class name --> toothbrush
# 0: 480x640 1 teddy bear, 1 toothbrush, 162.1ms
# Speed: 5.3ms preprocess, 162.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.36
# Class name --> teddy bear
# Confidence ---> 0.26
# Class name --> toothbrush
# 0: 480x640 1 teddy bear, 1 toothbrush, 152.5ms
# Speed: 1.4ms preprocess, 152.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.65
# Class name --> teddy bear
# Confidence ---> 0.42
# Class name --> clock
# 0: 480x640 1 clock, 1 teddy bear, 151.0ms
# Speed: 1.4ms preprocess, 151.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.58
# Class name --> teddy bear
# 0: 480x640 1 teddy bear, 153.1ms
# Speed: 1.6ms preprocess, 153.1ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.38
# Class name --> teddy bear
# 0: 480x640 1 teddy bear, 152.1ms
# Speed: 1.5ms preprocess, 152.1ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.61
# Class name --> teddy bear
# Confidence ---> 0.39
# Class name --> clock
# Confidence ---> 0.34
# Class name --> toothbrush
# Confidence ---> 0.29
# Class name --> knife
# 0: 480x640 1 knife, 1 clock, 1 teddy bear, 1 toothbrush, 147.2ms
# Speed: 2.1ms preprocess, 147.2ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.63
# Class name --> teddy bear
# Confidence ---> 0.39
# Class name --> knife
# Confidence ---> 0.3
# Class name --> clock
# 0: 480x640 1 knife, 1 clock, 1 teddy bear, 151.1ms
# Speed: 1.8ms preprocess, 151.1ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.41
# Class name --> teddy bear
# Confidence ---> 0.35
# Class name --> cup
# Confidence ---> 0.29
# Class name --> cup
# Confidence ---> 0.26
# Class name --> knife
# 0: 480x640 2 cups, 1 knife, 1 teddy bear, 146.1ms
# Speed: 1.6ms preprocess, 146.1ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.5
# Class name --> teddy bear
# Confidence ---> 0.47
# Class name --> clock
# 0: 480x640 1 clock, 1 teddy bear, 148.4ms
# Speed: 1.7ms preprocess, 148.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.68
# Class name --> teddy bear
# Confidence ---> 0.39
# Class name --> knife
# 0: 480x640 1 knife, 1 teddy bear, 154.0ms
# Speed: 1.3ms preprocess, 154.0ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.67
# Class name --> teddy bear
# Confidence ---> 0.36
# Class name --> knife
# 0: 480x640 1 knife, 1 teddy bear, 151.2ms
# Speed: 1.4ms preprocess, 151.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.68
# Class name --> teddy bear
# Confidence ---> 0.34
# Class name --> clock
# Confidence ---> 0.3
# Class name --> knife
# 0: 480x640 1 knife, 1 clock, 1 teddy bear, 146.6ms
# Speed: 2.0ms preprocess, 146.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.67
# Class name --> teddy bear
# 0: 480x640 1 teddy bear, 146.0ms
# Speed: 1.8ms preprocess, 146.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.66
# Class name --> teddy bear
# Confidence ---> 0.36
# Class name --> aeroplane
# 0: 480x640 1 airplane, 1 teddy bear, 151.4ms
# Speed: 1.6ms preprocess, 151.4ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.72
# Class name --> teddy bear
# Confidence ---> 0.64
# Class name --> clock
# Confidence ---> 0.27
# Class name --> knife
# 0: 480x640 1 knife, 1 clock, 1 teddy bear, 152.1ms
# Speed: 1.4ms preprocess, 152.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.7
# Class name --> teddy bear
# Confidence ---> 0.65
# Class name --> clock
# Confidence ---> 0.39
# Class name --> knife
# 0: 480x640 1 knife, 1 clock, 1 teddy bear, 149.4ms
# Speed: 1.4ms preprocess, 149.4ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.55
# Class name --> teddy bear
# Confidence ---> 0.37
# Class name --> cup
# 0: 480x640 1 cup, 1 teddy bear, 147.2ms
# Speed: 1.5ms preprocess, 147.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.78
# Class name --> teddy bear
# Confidence ---> 0.67
# Class name --> clock
# Confidence ---> 0.4
# Class name --> knife
# 0: 480x640 1 knife, 1 clock, 1 teddy bear, 151.3ms
# Speed: 1.4ms preprocess, 151.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.72
# Class name --> teddy bear
# Confidence ---> 0.49
# Class name --> clock
# Confidence ---> 0.47
# Class name --> knife
# 0: 480x640 1 knife, 1 clock, 1 teddy bear, 152.2ms
# Speed: 1.4ms preprocess, 152.2ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.73
# Class name --> teddy bear
# Confidence ---> 0.47
# Class name --> knife
# Confidence ---> 0.46
# Class name --> clock
# 0: 480x640 1 knife, 1 clock, 1 teddy bear, 152.1ms
# Speed: 1.3ms preprocess, 152.1ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.64
# Class name --> teddy bear
# Confidence ---> 0.4
# Class name --> knife
# 0: 480x640 1 knife, 1 teddy bear, 150.7ms
# Speed: 1.6ms preprocess, 150.7ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.7
# Class name --> teddy bear
# Confidence ---> 0.35
# Class name --> knife
# Confidence ---> 0.32
# Class name --> clock
# 0: 480x640 1 knife, 1 clock, 1 teddy bear, 149.2ms
# Speed: 1.3ms preprocess, 149.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.72
# Class name --> teddy bear
# Confidence ---> 0.52
# Class name --> knife
# Confidence ---> 0.28
# Class name --> clock
# 0: 480x640 1 knife, 1 clock, 1 teddy bear, 182.3ms
# Speed: 1.5ms preprocess, 182.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.76
# Class name --> teddy bear
# Confidence ---> 0.54
# Class name --> clock
# 0: 480x640 1 clock, 1 teddy bear, 154.0ms
# Speed: 2.0ms preprocess, 154.0ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.72
# Class name --> teddy bear
# Confidence ---> 0.26
# Class name --> cup
# 0: 480x640 1 cup, 1 teddy bear, 152.2ms
# Speed: 1.6ms preprocess, 152.2ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.69
# Class name --> teddy bear
# Confidence ---> 0.51
# Class name --> knife
# 0: 480x640 1 knife, 1 teddy bear, 150.9ms
# Speed: 1.4ms preprocess, 150.9ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.62
# Class name --> teddy bear
# Confidence ---> 0.41
# Class name --> clock
# Confidence ---> 0.31
# Class name --> knife
# 0: 480x640 1 knife, 1 clock, 1 teddy bear, 150.1ms
# Speed: 1.4ms preprocess, 150.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.51
# Class name --> teddy bear
# Confidence ---> 0.45
# Class name --> knife
# Confidence ---> 0.42
# Class name --> clock
# 0: 480x640 1 knife, 1 clock, 1 teddy bear, 149.6ms
# Speed: 2.5ms preprocess, 149.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.76
# Class name --> teddy bear
# Confidence ---> 0.76
# Class name --> clock
# Confidence ---> 0.4
# Class name --> knife
# 0: 480x640 1 knife, 1 clock, 1 teddy bear, 150.3ms
# Speed: 1.8ms preprocess, 150.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.67
# Class name --> teddy bear
# Confidence ---> 0.33
# Class name --> clock
# Confidence ---> 0.31
# Class name --> knife
# 0: 480x640 1 knife, 1 clock, 1 teddy bear, 156.3ms
# Speed: 2.1ms preprocess, 156.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.75
# Class name --> clock
# Confidence ---> 0.7
# Class name --> teddy bear
# Confidence ---> 0.34
# Class name --> knife
# Confidence ---> 0.27
# Class name --> scissors
# 0: 480x640 1 knife, 1 clock, 1 scissors, 1 teddy bear, 151.1ms
# Speed: 1.6ms preprocess, 151.1ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.78
# Class name --> teddy bear
# Confidence ---> 0.78
# Class name --> clock
# Confidence ---> 0.45
# Class name --> knife
# 0: 480x640 1 knife, 1 clock, 1 teddy bear, 149.7ms
# Speed: 1.4ms preprocess, 149.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.79
# Class name --> teddy bear
# Confidence ---> 0.74
# Class name --> clock
# Confidence ---> 0.48
# Class name --> knife
# 0: 480x640 1 knife, 1 clock, 1 teddy bear, 153.8ms
# Speed: 1.4ms preprocess, 153.8ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.69
# Class name --> teddy bear
# Confidence ---> 0.46
# Class name --> knife
# Confidence ---> 0.46
# Class name --> clock
# 0: 480x640 1 knife, 1 clock, 1 teddy bear, 155.7ms
# Speed: 1.6ms preprocess, 155.7ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.7
# Class name --> teddy bear
# Confidence ---> 0.57
# Class name --> clock
# Confidence ---> 0.5
# Class name --> knife
# 0: 480x640 1 knife, 1 clock, 1 teddy bear, 155.7ms
# Speed: 1.4ms preprocess, 155.7ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.72
# Class name --> teddy bear
# Confidence ---> 0.57
# Class name --> knife
# Confidence ---> 0.42
# Class name --> clock
# 0: 480x640 1 knife, 1 clock, 1 teddy bear, 151.2ms
# Speed: 1.3ms preprocess, 151.2ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.71
# Class name --> teddy bear
# Confidence ---> 0.46
# Class name --> knife
# Confidence ---> 0.34
# Class name --> clock
# 0: 480x640 1 knife, 1 clock, 1 teddy bear, 147.8ms
# Speed: 1.4ms preprocess, 147.8ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.72
# Class name --> teddy bear
# Confidence ---> 0.54
# Class name --> clock
# Confidence ---> 0.42
# Class name --> knife
# 0: 480x640 1 knife, 1 clock, 1 teddy bear, 152.3ms
# Speed: 1.5ms preprocess, 152.3ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.77
# Class name --> teddy bear
# Confidence ---> 0.48
# Class name --> clock
# Confidence ---> 0.36
# Class name --> knife
# 0: 480x640 1 knife, 1 clock, 1 teddy bear, 147.6ms
# Speed: 1.4ms preprocess, 147.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.78
# Class name --> teddy bear
# Confidence ---> 0.36
# Class name --> knife
# 0: 480x640 1 knife, 1 teddy bear, 155.0ms
# Speed: 1.4ms preprocess, 155.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.81
# Class name --> teddy bear
# Confidence ---> 0.39
# Class name --> knife
# 0: 480x640 1 knife, 1 teddy bear, 153.5ms
# Speed: 1.4ms preprocess, 153.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.63
# Class name --> teddy bear
# Confidence ---> 0.51
# Class name --> knife
# 0: 480x640 1 knife, 1 teddy bear, 149.2ms
# Speed: 1.9ms preprocess, 149.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.8
# Class name --> teddy bear
# Confidence ---> 0.45
# Class name --> knife
# Confidence ---> 0.43
# Class name --> clock
# 0: 480x640 1 knife, 1 clock, 1 teddy bear, 149.9ms
# Speed: 1.6ms preprocess, 149.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.74
# Class name --> teddy bear
# Confidence ---> 0.35
# Class name --> scissors
# Confidence ---> 0.27
# Class name --> knife
# 0: 480x640 1 knife, 1 scissors, 1 teddy bear, 152.2ms
# Speed: 1.5ms preprocess, 152.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.77
# Class name --> teddy bear
# Confidence ---> 0.53
# Class name --> clock
# 0: 480x640 1 clock, 1 teddy bear, 163.0ms
# Speed: 4.1ms preprocess, 163.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.74
# Class name --> teddy bear
# Confidence ---> 0.63
# Class name --> clock
# Confidence ---> 0.37
# Class name --> knife
# 0: 480x640 1 knife, 1 clock, 1 teddy bear, 150.0ms
# Speed: 1.7ms preprocess, 150.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.75
# Class name --> teddy bear
# Confidence ---> 0.66
# Class name --> clock
# Confidence ---> 0.34
# Class name --> knife
# 0: 480x640 1 knife, 1 clock, 1 teddy bear, 150.9ms
# Speed: 1.8ms preprocess, 150.9ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.69
# Class name --> teddy bear
# Confidence ---> 0.41
# Class name --> knife
# 0: 480x640 1 knife, 1 teddy bear, 146.8ms
# Speed: 1.6ms preprocess, 146.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.61
# Class name --> teddy bear
# Confidence ---> 0.43
# Class name --> clock
# Confidence ---> 0.38
# Class name --> knife
# 0: 480x640 1 knife, 1 clock, 1 teddy bear, 145.3ms
# Speed: 1.4ms preprocess, 145.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.72
# Class name --> teddy bear
# Confidence ---> 0.42
# Class name --> knife
# 0: 480x640 1 knife, 1 teddy bear, 152.9ms
# Speed: 1.3ms preprocess, 152.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.64
# Class name --> teddy bear
# Confidence ---> 0.33
# Class name --> clock
# Confidence ---> 0.32
# Class name --> knife
# 0: 480x640 1 knife, 1 clock, 1 teddy bear, 149.2ms
# Speed: 1.4ms preprocess, 149.2ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.71
# Class name --> teddy bear
# Confidence ---> 0.45
# Class name --> knife
# Confidence ---> 0.38
# Class name --> clock
# 0: 480x640 1 knife, 1 clock, 1 teddy bear, 149.1ms
# Speed: 1.5ms preprocess, 149.1ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.6
# Class name --> teddy bear
# Confidence ---> 0.44
# Class name --> clock
# Confidence ---> 0.34
# Class name --> knife
# Confidence ---> 0.29
# Class name --> chair
# 0: 480x640 1 knife, 1 chair, 1 clock, 1 teddy bear, 151.5ms
# Speed: 1.3ms preprocess, 151.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.76
# Class name --> teddy bear
# Confidence ---> 0.52
# Class name --> clock
# Confidence ---> 0.38
# Class name --> knife
# Confidence ---> 0.28
# Class name --> chair
# 0: 480x640 1 knife, 1 chair, 1 clock, 1 teddy bear, 149.5ms
# Speed: 1.4ms preprocess, 149.5ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.68
# Class name --> teddy bear
# Confidence ---> 0.44
# Class name --> clock
# Confidence ---> 0.39
# Class name --> knife
# 0: 480x640 1 knife, 1 clock, 1 teddy bear, 149.3ms
# Speed: 1.5ms preprocess, 149.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.63
# Class name --> teddy bear
# Confidence ---> 0.48
# Class name --> knife
# Confidence ---> 0.26
# Class name --> clock
# 0: 480x640 1 knife, 1 clock, 1 teddy bear, 150.4ms
# Speed: 1.4ms preprocess, 150.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.61
# Class name --> teddy bear
# 0: 480x640 1 teddy bear, 150.6ms
# Speed: 1.3ms preprocess, 150.6ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.48
# Class name --> teddy bear
# Confidence ---> 0.26
# Class name --> clock
# 0: 480x640 1 clock, 1 teddy bear, 157.0ms
# Speed: 1.6ms preprocess, 157.0ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.35
# Class name --> teddy bear
# 0: 480x640 1 teddy bear, 166.8ms
# Speed: 1.9ms preprocess, 166.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 151.4ms
# Speed: 1.3ms preprocess, 151.4ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 149.8ms
# Speed: 1.6ms preprocess, 149.8ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 148.2ms
# Speed: 1.6ms preprocess, 148.2ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 150.7ms
# Speed: 1.8ms preprocess, 150.7ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.39
# Class name --> teddy bear
# 0: 480x640 1 teddy bear, 154.7ms
# Speed: 2.3ms preprocess, 154.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.32
# Class name --> mouse
# 0: 480x640 1 mouse, 151.3ms
# Speed: 2.6ms preprocess, 151.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 150.4ms
# Speed: 1.5ms preprocess, 150.4ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 179.6ms
# Speed: 1.3ms preprocess, 179.6ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.29
# Class name --> cup
# 0: 480x640 1 cup, 153.7ms
# Speed: 1.3ms preprocess, 153.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.32
# Class name --> mouse
# 0: 480x640 1 mouse, 157.7ms
# Speed: 1.4ms preprocess, 157.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.57
# Class name --> orange
# Confidence ---> 0.28
# Class name --> tvmonitor
# 0: 480x640 1 orange, 1 tv, 155.5ms
# Speed: 1.7ms preprocess, 155.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.47
# Class name --> vase
# Confidence ---> 0.4
# Class name --> orange
# Confidence ---> 0.3
# Class name --> diningtable
# Confidence ---> 0.3
# Class name --> bowl
# 0: 480x640 1 bowl, 1 orange, 1 dining table, 1 vase, 156.0ms
# Speed: 1.7ms preprocess, 156.0ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.45
# Class name --> cup
# Confidence ---> 0.44
# Class name --> vase
# Confidence ---> 0.35
# Class name --> orange
# 0: 480x640 1 cup, 1 orange, 1 vase, 148.6ms
# Speed: 1.5ms preprocess, 148.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.69
# Class name --> cup
# Confidence ---> 0.39
# Class name --> vase
# Confidence ---> 0.31
# Class name --> teddy bear
# Confidence ---> 0.3
# Class name --> orange
# 0: 480x640 1 cup, 1 orange, 1 vase, 1 teddy bear, 149.9ms
# Speed: 1.3ms preprocess, 149.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.62
# Class name --> cup
# Confidence ---> 0.52
# Class name --> teddy bear
# Confidence ---> 0.46
# Class name --> vase
# Confidence ---> 0.37
# Class name --> orange
# 0: 480x640 1 cup, 1 orange, 1 vase, 1 teddy bear, 147.6ms
# Speed: 1.3ms preprocess, 147.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.64
# Class name --> vase
# Confidence ---> 0.48
# Class name --> cup
# Confidence ---> 0.39
# Class name --> teddy bear
# Confidence ---> 0.28
# Class name --> orange
# 0: 480x640 1 cup, 1 orange, 1 vase, 1 teddy bear, 150.8ms
# Speed: 1.5ms preprocess, 150.8ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.67
# Class name --> vase
# Confidence ---> 0.53
# Class name --> teddy bear
# Confidence ---> 0.49
# Class name --> cup
# Confidence ---> 0.27
# Class name --> orange
# 0: 480x640 1 cup, 1 orange, 1 vase, 1 teddy bear, 146.4ms
# Speed: 1.7ms preprocess, 146.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.61
# Class name --> cup
# Confidence ---> 0.36
# Class name --> orange
# Confidence ---> 0.3
# Class name --> vase
# Confidence ---> 0.29
# Class name --> teddy bear
# 0: 480x640 1 cup, 1 orange, 1 vase, 1 teddy bear, 144.5ms
# Speed: 1.8ms preprocess, 144.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.46
# Class name --> cup
# Confidence ---> 0.42
# Class name --> knife
# Confidence ---> 0.39
# Class name --> vase
# Confidence ---> 0.38
# Class name --> orange
# 0: 480x640 1 cup, 1 knife, 1 orange, 1 vase, 148.1ms
# Speed: 1.5ms preprocess, 148.1ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.62
# Class name --> cup
# Confidence ---> 0.42
# Class name --> orange
# Confidence ---> 0.38
# Class name --> knife
# Confidence ---> 0.32
# Class name --> vase
# 0: 480x640 1 cup, 1 knife, 1 orange, 1 vase, 147.0ms
# Speed: 1.5ms preprocess, 147.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.47
# Class name --> vase
# Confidence ---> 0.29
# Class name --> orange
# Confidence ---> 0.28
# Class name --> cup
# Confidence ---> 0.26
# Class name --> cup
# 0: 480x640 2 cups, 1 orange, 1 vase, 159.2ms
# Speed: 1.7ms preprocess, 159.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.54
# Class name --> vase
# Confidence ---> 0.44
# Class name --> cup
# Confidence ---> 0.29
# Class name --> orange
# 0: 480x640 1 cup, 1 orange, 1 vase, 154.3ms
# Speed: 2.1ms preprocess, 154.3ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.77
# Class name --> vase
# Confidence ---> 0.4
# Class name --> cup
# Confidence ---> 0.29
# Class name --> tvmonitor
# Confidence ---> 0.26
# Class name --> teddy bear
# 0: 480x640 1 cup, 1 tv, 1 vase, 1 teddy bear, 146.8ms
# Speed: 2.1ms preprocess, 146.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.58
# Class name --> orange
# Confidence ---> 0.56
# Class name --> vase
# 0: 480x640 1 orange, 1 vase, 148.6ms
# Speed: 1.5ms preprocess, 148.6ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.59
# Class name --> vase
# Confidence ---> 0.41
# Class name --> cup
# Confidence ---> 0.37
# Class name --> orange
# 0: 480x640 1 cup, 1 orange, 1 vase, 152.4ms
# ...
# 0: 480x640 1 bowl, 1 dining table, 1 tv, 1 teddy bear, 149.4ms
# Speed: 1.4ms preprocess, 149.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.58
# Class name --> teddy bear
# Confidence ---> 0.31
# Class name --> tvmonitor
# Confidence ---> 0.28
# Class name --> diningtable
# 0: 480x640 1 dining table, 1 tv, 1 teddy bear, 155.0ms
# Speed: 2.1ms preprocess, 155.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.52
# Class name --> cup
# Confidence ---> 0.47
# Class name --> teddy bear
# Confidence ---> 0.39
# Class name --> tvmonitor
# 0: 480x640 1 cup, 1 tv, 1 teddy bear, 148.0ms
# Speed: 2.4ms preprocess, 148.0ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.39
# Class name --> teddy bear
# Confidence ---> 0.33
# Class name --> tvmonitor
# Confidence ---> 0.31
# Class name --> bowl
# 0: 480x640 1 bowl, 1 tv, 1 teddy bear, 157.0ms
# Speed: 1.5ms preprocess, 157.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.3
# Class name --> tvmonitor
# Confidence ---> 0.29
# Class name --> teddy bear
# 0: 480x640 1 tv, 1 teddy bear, 148.8ms
# Speed: 1.3ms preprocess, 148.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.4
# Class name --> teddy bear
# Confidence ---> 0.33
# Class name --> diningtable
# Confidence ---> 0.27
# Class name --> tvmonitor
# 0: 480x640 1 dining table, 1 tv, 1 teddy bear, 148.7ms
# Speed: 1.3ms preprocess, 148.7ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.36
# Class name --> diningtable
# Confidence ---> 0.35
# Class name --> teddy bear
# Confidence ---> 0.31
# Class name --> tvmonitor
# Confidence ---> 0.31
# Class name --> cup
# 0: 480x640 1 cup, 1 dining table, 1 tv, 1 teddy bear, 148.5ms
# Speed: 1.4ms preprocess, 148.5ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.42
# Class name --> tvmonitor
# Confidence ---> 0.41
# Class name --> teddy bear
# Confidence ---> 0.35
# Class name --> cup
# 0: 480x640 1 cup, 1 tv, 1 teddy bear, 147.6ms
# Speed: 1.5ms preprocess, 147.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.48
# Class name --> teddy bear
# Confidence ---> 0.43
# Class name --> tvmonitor
# Confidence ---> 0.26
# Class name --> diningtable
# 0: 480x640 1 dining table, 1 tv, 1 teddy bear, 146.9ms
# Speed: 1.9ms preprocess, 146.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.52
# Class name --> teddy bear
# Confidence ---> 0.41
# Class name --> tvmonitor
# Confidence ---> 0.29
# Class name --> diningtable
# 0: 480x640 1 dining table, 1 tv, 1 teddy bear, 143.9ms
# Speed: 1.5ms preprocess, 143.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.5
# Class name --> teddy bear
# Confidence ---> 0.36
# Class name --> diningtable
# Confidence ---> 0.31
# Class name --> cup
# Confidence ---> 0.29
# Class name --> tvmonitor
# 0: 480x640 1 cup, 1 dining table, 1 tv, 1 teddy bear, 148.6ms
# Speed: 1.7ms preprocess, 148.6ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.54
# Class name --> teddy bear
# Confidence ---> 0.29
# Class name --> diningtable
# Confidence ---> 0.29
# Class name --> tvmonitor
# Confidence ---> 0.27
# Class name --> knife
# 0: 480x640 1 knife, 1 dining table, 1 tv, 1 teddy bear, 151.0ms
# Speed: 1.5ms preprocess, 151.0ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.57
# Class name --> teddy bear
# Confidence ---> 0.33
# Class name --> diningtable
# Confidence ---> 0.3
# Class name --> tvmonitor
# Confidence ---> 0.27
# Class name --> cup
# Confidence ---> 0.26
# Class name --> bowl
# 0: 480x640 1 cup, 1 bowl, 1 dining table, 1 tv, 1 teddy bear, 147.7ms
# Speed: 1.4ms preprocess, 147.7ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.58
# Class name --> teddy bear
# Confidence ---> 0.34
# Class name --> diningtable
# Confidence ---> 0.27
# Class name --> tvmonitor
# 0: 480x640 1 dining table, 1 tv, 1 teddy bear, 149.3ms
# Speed: 1.3ms preprocess, 149.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.54
# Class name --> teddy bear
# Confidence ---> 0.32
# Class name --> tvmonitor
# Confidence ---> 0.28
# Class name --> diningtable
# 0: 480x640 1 dining table, 1 tv, 1 teddy bear, 148.4ms
# Speed: 1.4ms preprocess, 148.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.64
# Class name --> teddy bear
# Confidence ---> 0.28
# Class name --> tvmonitor
# 0: 480x640 1 tv, 1 teddy bear, 160.5ms
# Speed: 1.3ms preprocess, 160.5ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.59
# Class name --> teddy bear
# 0: 480x640 1 teddy bear, 154.5ms
# Speed: 1.7ms preprocess, 154.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.44
# Class name --> teddy bear
# Confidence ---> 0.3
# Class name --> tvmonitor
# Confidence ---> 0.28
# Class name --> cup
# 0: 480x640 1 cup, 1 tv, 1 teddy bear, 149.1ms
# Speed: 1.3ms preprocess, 149.1ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.43
# Class name --> teddy bear
# Confidence ---> 0.32
# Class name --> cup
# Confidence ---> 0.26
# Class name --> tvmonitor
# 0: 480x640 1 cup, 1 tv, 1 teddy bear, 149.7ms
# Speed: 1.4ms preprocess, 149.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.48
# Class name --> cup
# Confidence ---> 0.34
# Class name --> tvmonitor
# 0: 480x640 1 cup, 1 tv, 153.3ms
# Speed: 1.7ms preprocess, 153.3ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.39
# Class name --> cup
# Confidence ---> 0.36
# Class name --> teddy bear
# Confidence ---> 0.32
# Class name --> tvmonitor
# 0: 480x640 1 cup, 1 tv, 1 teddy bear, 152.5ms
# Speed: 1.5ms preprocess, 152.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.46
# Class name --> cup
# Confidence ---> 0.37
# Class name --> tvmonitor
# Confidence ---> 0.27
# Class name --> teddy bear
# 0: 480x640 1 cup, 1 tv, 1 teddy bear, 154.4ms
# Speed: 1.9ms preprocess, 154.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.49
# Class name --> cup
# Confidence ---> 0.46
# Class name --> teddy bear
# Confidence ---> 0.43
# Class name --> cup
# Confidence ---> 0.3
# Class name --> diningtable
# Confidence ---> 0.3
# Class name --> tvmonitor
# 0: 480x640 2 cups, 1 dining table, 1 tv, 1 teddy bear, 151.4ms
# Speed: 1.3ms preprocess, 151.4ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.61
# Class name --> teddy bear
# Confidence ---> 0.32
# Class name --> tvmonitor
# Confidence ---> 0.32
# Class name --> cup
# 0: 480x640 1 cup, 1 tv, 1 teddy bear, 152.7ms
# Speed: 1.3ms preprocess, 152.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.39
# Class name --> tvmonitor
# Confidence ---> 0.36
# Class name --> cup
# 0: 480x640 1 cup, 1 tv, 147.8ms
# Speed: 1.4ms preprocess, 147.8ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.36
# Class name --> cup
# Confidence ---> 0.35
# Class name --> teddy bear
# Confidence ---> 0.32
# Class name --> cup
# Confidence ---> 0.32
# Class name --> tvmonitor
# 0: 480x640 2 cups, 1 tv, 1 teddy bear, 149.0ms
# Speed: 1.4ms preprocess, 149.0ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.29
# Class name --> cup
# Confidence ---> 0.26
# Class name --> teddy bear
# 0: 480x640 1 cup, 1 teddy bear, 149.3ms
# Speed: 1.4ms preprocess, 149.3ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.52
# Class name --> teddy bear
# Confidence ---> 0.45
# Class name --> tvmonitor
# 0: 480x640 1 tv, 1 teddy bear, 146.0ms
# Speed: 1.7ms preprocess, 146.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.63
# Class name --> teddy bear
# Confidence ---> 0.5
# Class name --> cup
# Confidence ---> 0.32
# Class name --> tvmonitor
# 0: 480x640 1 cup, 1 tv, 1 teddy bear, 150.6ms
# Speed: 2.0ms preprocess, 150.6ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.69
# Class name --> teddy bear
# Confidence ---> 0.61
# Class name --> cup
# Confidence ---> 0.39
# Class name --> tvmonitor
# 0: 480x640 1 cup, 1 tv, 1 teddy bear, 147.0ms
# Speed: 1.5ms preprocess, 147.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.46
# Class name --> cup
# Confidence ---> 0.45
# Class name --> tvmonitor
# Confidence ---> 0.38
# Class name --> teddy bear
# 0: 480x640 1 cup, 1 tv, 1 teddy bear, 148.7ms
# Speed: 1.5ms preprocess, 148.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.68
# Class name --> teddy bear
# Confidence ---> 0.61
# Class name --> cup
# Confidence ---> 0.27
# Class name --> tvmonitor
# 0: 480x640 1 cup, 1 tv, 1 teddy bear, 149.6ms
# Speed: 1.6ms preprocess, 149.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.61
# Class name --> cup
# Confidence ---> 0.49
# Class name --> teddy bear
# Confidence ---> 0.36
# Class name --> tvmonitor
# 0: 480x640 1 cup, 1 tv, 1 teddy bear, 148.8ms
# Speed: 1.5ms preprocess, 148.8ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.62
# Class name --> teddy bear
# Confidence ---> 0.51
# Class name --> cup
# Confidence ---> 0.38
# Class name --> tvmonitor
# 0: 480x640 1 cup, 1 tv, 1 teddy bear, 147.5ms
# Speed: 1.4ms preprocess, 147.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.58
# Class name --> teddy bear
# Confidence ---> 0.46
# Class name --> tvmonitor
# Confidence ---> 0.36
# Class name --> cup
# 0: 480x640 1 cup, 1 tv, 1 teddy bear, 152.3ms
# Speed: 1.3ms preprocess, 152.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.48
# Class name --> teddy bear
# Confidence ---> 0.34
# Class name --> cup
# Confidence ---> 0.26
# Class name --> tvmonitor
# 0: 480x640 1 cup, 1 tv, 1 teddy bear, 161.1ms
# Speed: 1.8ms preprocess, 161.1ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.43
# Class name --> cup
# Confidence ---> 0.43
# Class name --> tvmonitor
# 0: 480x640 1 cup, 1 tv, 155.2ms
# Speed: 2.1ms preprocess, 155.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.45
# Class name --> cup
# Confidence ---> 0.44
# Class name --> teddy bear
# Confidence ---> 0.33
# Class name --> tvmonitor
# 0: 480x640 1 cup, 1 tv, 1 teddy bear, 153.1ms
# Speed: 1.5ms preprocess, 153.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.7
# Class name --> cup
# Confidence ---> 0.6
# Class name --> teddy bear
# Confidence ---> 0.44
# Class name --> diningtable
# Confidence ---> 0.36
# Class name --> tvmonitor
# 0: 480x640 1 cup, 1 dining table, 1 tv, 1 teddy bear, 160.1ms
# Speed: 1.4ms preprocess, 160.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.63
# Class name --> teddy bear
# Confidence ---> 0.32
# Class name --> tvmonitor
# 0: 480x640 1 tv, 1 teddy bear, 153.2ms
# Speed: 1.5ms preprocess, 153.2ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.72
# Class name --> teddy bear
# Confidence ---> 0.45
# Class name --> mouse
# 0: 480x640 1 mouse, 1 teddy bear, 186.9ms
# Speed: 1.2ms preprocess, 186.9ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.4
# Class name --> teddy bear
# 0: 480x640 1 teddy bear, 145.7ms
# Speed: 1.4ms preprocess, 145.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.56
# Class name --> teddy bear
# Confidence ---> 0.29
# Class name --> tvmonitor
# 0: 480x640 1 tv, 1 teddy bear, 154.2ms
# Speed: 1.3ms preprocess, 154.2ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.48
# Class name --> teddy bear
# Confidence ---> 0.26
# Class name --> tvmonitor
# 0: 480x640 1 tv, 1 teddy bear, 159.2ms
# Speed: 1.2ms preprocess, 159.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.54
# Class name --> teddy bear
# 0: 480x640 1 teddy bear, 152.9ms
# Speed: 1.5ms preprocess, 152.9ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.52
# Class name --> teddy bear
# Confidence ---> 0.26
# Class name --> tvmonitor
# 0: 480x640 1 tv, 1 teddy bear, 149.0ms
# Speed: 1.6ms preprocess, 149.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.49
# Class name --> teddy bear
# 0: 480x640 1 teddy bear, 148.3ms
# Speed: 1.9ms preprocess, 148.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.39
# Class name --> teddy bear
# Confidence ---> 0.26
# Class name --> diningtable
# Confidence ---> 0.26
# Class name --> tvmonitor
# 0: 480x640 1 dining table, 1 tv, 1 teddy bear, 150.0ms
# Speed: 2.1ms preprocess, 150.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.52
# Class name --> teddy bear
# 0: 480x640 1 teddy bear, 150.4ms
# Speed: 1.2ms preprocess, 150.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.63
# Class name --> teddy bear
# Confidence ---> 0.44
# Class name --> diningtable
# 0: 480x640 1 dining table, 1 teddy bear, 151.5ms
# Speed: 1.9ms preprocess, 151.5ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.53
# Class name --> teddy bear
# Confidence ---> 0.37
# Class name --> diningtable
# Confidence ---> 0.33
# Class name --> tvmonitor
# 0: 480x640 1 dining table, 1 tv, 1 teddy bear, 157.9ms
# Speed: 1.7ms preprocess, 157.9ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.37
# Class name --> teddy bear
# 0: 480x640 1 teddy bear, 153.0ms
# Speed: 2.0ms preprocess, 153.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.3
# Class name --> teddy bear
# 0: 480x640 1 teddy bear, 149.8ms
# Speed: 1.5ms preprocess, 149.8ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.38
# Class name --> teddy bear
# Confidence ---> 0.26
# Class name --> tvmonitor
# 0: 480x640 1 tv, 1 teddy bear, 160.3ms
# Speed: 5.2ms preprocess, 160.3ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.36
# Class name --> tvmonitor
# Confidence ---> 0.3
# Class name --> teddy bear
# 0: 480x640 1 tv, 1 teddy bear, 154.4ms
# Speed: 1.5ms preprocess, 154.4ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.26
# Class name --> diningtable
# 0: 480x640 1 dining table, 151.9ms
# Speed: 1.5ms preprocess, 151.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.53
# Class name --> teddy bear
# Confidence ---> 0.29
# Class name --> diningtable
# 0: 480x640 1 dining table, 1 teddy bear, 151.9ms
# Speed: 1.4ms preprocess, 151.9ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.44
# Class name --> teddy bear
# Confidence ---> 0.4
# Class name --> tvmonitor
# Confidence ---> 0.36
# Class name --> diningtable
# 0: 480x640 1 dining table, 1 tv, 1 teddy bear, 161.7ms
# Speed: 1.4ms preprocess, 161.7ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.5
# Class name --> teddy bear
# Confidence ---> 0.43
# Class name --> tvmonitor
# Confidence ---> 0.35
# Class name --> diningtable
# 0: 480x640 1 dining table, 1 tv, 1 teddy bear, 153.7ms
# Speed: 1.6ms preprocess, 153.7ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.49
# Class name --> teddy bear
# Confidence ---> 0.47
# Class name --> tvmonitor
# Confidence ---> 0.4
# Class name --> diningtable
# 0: 480x640 1 dining table, 1 tv, 1 teddy bear, 152.0ms
# Speed: 1.6ms preprocess, 152.0ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# Confidence ---> 0.56
# Class name --> teddy bear
# Confidence ---> 0.39
# Class name --> tvmonitor
# Confidence ---> 0.34
# Class name --> diningtable
# 0: 480x640 1 dining table, 1 tv, 1 teddy bear, 151.6ms
# Speed: 1.7ms preprocess, 151.6ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)

# %% [markdown]
# # (讀取YT影片辨識)

# %%
# !pip3 install pafy
# Out:
# Collecting pafy
#   Downloading pafy-0.5.5-py2.py3-none-any.whl (35 kB)
# Installing collected packages: pafy
# Successfully installed pafy-0.5.5

# %%
# !pip3 install youtube-dl
# Out:
# Collecting youtube-dl
#   Downloading youtube_dl-2021.12.17-py2.py3-none-any.whl (1.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 8.1 MB/s eta 0:00:0000:0100:01
# Installing collected packages: youtube-dl
# Successfully installed youtube-dl-2021.12.17

# %%
from ultralytics import YOLO
import cv2, pafy, vlc


url = "https://www.youtube.com/watch?v=zBoVupqxTYY"
video = pafy.new(url)
best = video.getbest(preftype="webm") #----->取得最佳解析度

# media = vlc.MediaPlayer(best.url)
cap2 = cv2.VideoCapture(best.url)
check,frame = cap2.read()
print(check, frame)

cv2.imshow('frame', frame)
if cv2.waitKey(1) == ord('q'):
    break

cap2.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# d:\anaconda\lib\site-packages\pafy\pafy.py in <module>
#      47     try:
# ---> 48         import youtube_dl
#      49         backend = "youtube-dl"
#
# ModuleNotFoundError: No module named 'youtube_dl'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13152\4207113504.py in <module>
#       1 from ultralytics import YOLO
# ----> 2 import cv2, pafy, vlc
#       3
#       4
#       5 url = "https://www.youtube.com/watch?v=zBoVupqxTYY"
#
# d:\anaconda\lib\site-packages\pafy\__init__.py in <module>
#       5
#       6 # External api
# ----> 7 from .pafy import new
#       8 from .pafy import set_api_key
#       9 from .pafy import load_cache, dump_cache
#
# d:\anaconda\lib\site-packages\pafy\pafy.py in <module>
#      49         backend = "youtube-dl"
#      50     except ImportError:
# ---> 51         raise ImportError(
#      52                "pafy: youtube-dl not found; you can use the internal backend by "
#      53                "setting the environmental variable PAFY_BACKEND to \"internal\". "
#
# ImportError: pafy: youtube-dl not found; you can use the internal backend by setting the environmental variable PAFY_BACKEND to "internal". It is not enabled by default because it is not as well maintained as the youtube-dl backend.

# %%
import pafy
print(pafy.__version__)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# d:\anaconda\lib\site-packages\pafy\pafy.py in <module>
#      47     try:
# ---> 48         import youtube_dl
#      49         backend = "youtube-dl"
#
# ModuleNotFoundError: No module named 'youtube_dl'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13152\203143995.py in <module>
# ----> 1 import pafy
#       2 print(pafy.__version__)
#
# d:\anaconda\lib\site-packages\pafy\__init__.py in <module>
#       5
#       6 # External api
# ----> 7 from .pafy import new
#       8 from .pafy import set_api_key
#       9 from .pafy import load_cache, dump_cache
#
# d:\anaconda\lib\site-packages\pafy\pafy.py in <module>
#      49         backend = "youtube-dl"
#      50     except ImportError:
# ---> 51         raise ImportError(
#      52                "pafy: youtube-dl not found; you can use the internal backend by "
#      53                "setting the environmental variable PAFY_BACKEND to \"internal\". "
#
# ImportError: pafy: youtube-dl not found; you can use the internal backend by setting the environmental variable PAFY_BACKEND to "internal". It is not enabled by default because it is not as well maintained as the youtube-dl backend.

# %%
from ultralytics import YOLO

# Load a model
model = YOLO('yolov8n.pt')  # load an official detection model
model = YOLO('yolov8n-seg.pt')  # load an official segmentation model

# Video Tracking
results = model.track(source="https://www.youtube.com/watch?v=zBoVupqxTYY", show=True, tracker="bytetrack.yaml")
