# %%
# https://ithelp.ithome.com.tw/articles/10311114

# %%
# !pip install ultralytics
# Out:
# ...
# WARNING: Ignoring invalid distribution -treamlit (d:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -treamlit (d:\anaconda\lib\site-packages)

# %%
# !yolo
# Out:
#     Arguments received: ['yolo']. Ultralytics 'yolo' commands use the following syntax:
#
#         yolo TASK MODE ARGS
#
#         Where   TASK (optional) is one of ('detect', 'segment', 'classify', 'pose')
#                 MODE (required) is one of ('train', 'val', 'predict', 'export', 'track', 'benchmark')
#                 ARGS (optional) are any number of custom 'arg=value' pairs like 'imgsz=320' that override defaults.
#                     See all ARGS at https://docs.ultralytics.com/usage/cfg or with 'yolo cfg'
#
#     1. Train a detection model for 10 epochs with an initial learning_rate of 0.01
#         yolo train data=coco128.yaml model=yolov8n.pt epochs=10 lr0=0.01
#
#     2. Predict a YouTube video using a pretrained segmentation model at image size 320:
#         yolo predict model=yolov8n-seg.pt source='https://youtu.be/LNwODJXcvt4' imgsz=320
#
#     3. Val a pretrained detection model at batch-size 1 and image size 640:
# ...

# %%
# !yolo predict model=yolov8n.pt source="https://ultralytics.com/images/bus.jpg"
# Out:
# Ultralytics YOLOv8.0.226 🚀 Python-3.9.13 torch-2.1.1+cpu CPU (Intel Core(TM) i5-9400 2.90GHz)
# YOLOv8n summary (fused): 168 layers, 3151904 parameters, 0 gradients, 8.7 GFLOPs
#
# ...
# ⚠️ Download failure, retrying 1/3 https://ultralytics.com/images/bus.jpg...
# image 1/1 d:\DL\1_7.Object_Detection\bus.jpg: 640x480 4 persons, 1 bus, 1 stop sign, 481.6ms
# Speed: 111.1ms preprocess, 481.6ms inference, 234.3ms postprocess per image at shape (1, 3, 640, 480)
# Results saved to runs\detect\predict3
# 💡 Learn more at https://docs.ultralytics.com/modes/predict
# #=#=#
# ##O#-#
#
# ######################################################################## 100.0%curl: (6) Could not resolve host: www.ultralytics.com
# ...
# ##O=#  #
#
# ######################################################################## 100.0%curl: (6) Could not resolve host: www.ultralytics.com
# ...
# #-#O=#  #
#
# ...

# %% [markdown]
# # (定位)

# %%
from ultralytics import YOLO

# Load a model
model = YOLO("./yolov8n.pt")  # load a pretrained model (recommended for training)

# 預測:會將檢測結果輸出到run/detect/predict資料夾內
results = model("images/tiger.jpg")

# 顯示物件類別
print(results[0].boxes.cls)
print()

# 顯示物件座標
print(results[0].boxes.xyxy)
# Out:
# image 1/1 d:\DL\1_7.Object_Detection\images\tiger.jpg: 640x608 1 cat, 138.1ms
# Speed: 5.0ms preprocess, 138.1ms inference, 10.0ms postprocess per image at shape (1, 3, 640, 608)
# tensor([15.])
#
# tensor([[  0.0000,  23.0031, 475.4391, 505.5215]])

# %% [markdown]
# # (分類)

# %%
from IPython.display import Image
Image1 = "img/bus.jpg"
Image2 = "img/tiger.jpg"



display(Image(Image1,width=500))
display(Image(Image2,width=500))

# %%
from PIL import Image

im1 = Image.open("images/tiger.jpg")#./bus.jpg

results = model.predict(source=im1, save=True) #----->save=True：存檔到predict資料夾
# Out:
# 0: 640x608 1 cat, 126.3ms
# Speed: 4.0ms preprocess, 126.3ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 608)
# Results saved to runs\detect\predict4

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
image0 = plt.imread('./runs/detect/predict/Tiger.jpg')
plt.imshow(image0)
plt.show()

# %%
image1 = plt.imread('./runs/detect/predict/bus.jpg')
plt.imshow(image1)
plt.show()

# %%
# 預測整個資料夾:
#results = model.predict(source="dogs", save=True)#, show=True
# 預測影片:
results = model.predict(source="img/美河市1.mp4", show=True, save=True)
# Out:
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (1/294) d:\DL\1_7.Object_Detection\img\美河市1.mp4: 640x384 7 persons, 101.4ms
# video 1/1 (2/294) d:\DL\1_7.Object_Detection\img\美河市1.mp4: 640x384 10 persons, 92.8ms
# video 1/1 (3/294) d:\DL\1_7.Object_Detection\img\美河市1.mp4: 640x384 9 persons, 1 truck, 76.7ms
# video 1/1 (4/294) d:\DL\1_7.Object_Detection\img\美河市1.mp4: 640x384 7 persons, 78.2ms
# ...
