# %%
from IPython.display import Image
# %matplotlib inline

# %%
Image(filename='img/cnn5.png', width=1000)

# %% [markdown]
# # 1.卷積層

# %%
print("卷積層")
Image(filename='img/cl.png', width=1000)
# Out:
# 卷積層

# %%
print("卷積層參數")
Image(filename='img/cl1.png', width=1000)
# Out:
# 卷積層參數

# %%
Image(filename='img/cl2.png', width=1000)

# %% [markdown]
# ### padding有填0,對圖片邊緣保留較多圖片特徵 /
# ### stides小,細節較多 /
# ### tf能填0或不填,pytorch一率填0 /
# ### 圖片預處理(縮小)---->避免map過大

# %%
Image(filename='img/cl3.png', width=1000)
