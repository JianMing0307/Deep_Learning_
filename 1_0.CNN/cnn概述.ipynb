# %%
from IPython.display import Image
# %matplotlib inline

# %% [markdown]
# # CNN概述

# %%
Image(filename='img/cnn0.png', width=1200)

# %%
Image(filename='img/cnn.png', width=1000)

# %%
Image(filename='img/cnn1.png', width=1000)

# %%
Image(filename='img/cnn2.png', width=1000)

# %%
Image(filename='img/cnn3.png', width=1500)

# %%
Image(filename='img/cnn4.png', width=1500)
