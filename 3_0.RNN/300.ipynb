# %% [markdown]
# #### Note :
# #### 詞向量必須3維 /
# #### RNN有前向與雙向2種，本單元只考慮前向 /
# #### 權重共享 /
# #### RNN一個輸入 : 1個詞向量or1句話

# %%
from IPython.display import Image
Images = ['img/1.jpg','img/4.jpg'] 

for path in Images:
    display(Image(filename=path))

# %%
Image('img/9.jpg') #----->Simple RNN無法處理序列教長的句子

# %%
from IPython.display import Image
Images = ['img/2.jpg','img/5.jpg','img/6.jpg','img/3.jpg'] #----->(h單一神經元裡包含步驟h0.h1.h2.h3....)

for path in Images:
    display(Image(filename=path))

# %% [markdown]
# #### Note :
# #### 權重是為了保持向量維度相同
# #### 只有最後一次的output(Ot)重要

# %%
Image('img/7.jpg') #----->權重是為了保持向量維度相同

# %%
Image('img/8.jpg')
