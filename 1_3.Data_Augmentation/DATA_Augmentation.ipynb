# %%
from IPython.display import Image
# %matplotlib inline

# %%
Image(filename='img/DA.png', width=1000)

# %%
Image(filename='img/DA1.png', width=1000)

#----->改色溫要考慮

# %%
Image(filename='img/dog.png', width=1000)
